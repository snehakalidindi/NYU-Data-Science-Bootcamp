# %%
import pandas as pd

df = pd.DataFrame(test) #dataframe - to load data
df = pd.read_csv("data.csv") #to read csv file
df = pd.read_excel("data.xlsx")  #to read excel file

df.to_string() #converts the data into string - all the data rows
df.head() #returns the first five rows with headers
df.tail() # returns the last five rows with headers
df.info() #returns the number of rows and non null values in each column
df.describe() #describes the mean, mode - standard deviation
df.shape #return number of row and columns - 2,3
df.columns # returns column names - Name, Age

df['Age'] = df['Age'] + 1
df['newcol'] = df['Age'] * 2
df[df['Age']>25]

df['Date'] = pd.to_datetime(df['Date'])
df['year'] = df['Date'].dt.year
df['month'] = df['Date'].dt.month
df['weekday'] = df['Date'].dt.day_name()

df['Name'].str.upper()
df['Name'].str.lower()
df['Name'].str.replace('a','@')
df['name'].str.contains('ne')

df['Age'].apply(lambda x:x+1)
df.applymap(str)
df.map('sneha':'S', 'Monika':'M')

df.sort_values('Age')
df.sort_values('Age', ascending=False)

df.duplicated()
df.drop_duplicates()

df.groupby('Name').mean()
df.groupby('Department')['Salary'].mean()
