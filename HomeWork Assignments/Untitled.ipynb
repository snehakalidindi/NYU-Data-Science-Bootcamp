# %%
import numpy as np

# Load the Iris dataset (only numeric columns)
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris_2d = np.genfromtxt(url, delimiter=',', dtype='float', usecols=[0,1,2,3])

# Display the first few rows
print(iris_2d[:5])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       3 # Load the Iris dataset (only numeric columns)
#       4 url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
# ----> 5 iris_2d = np.genfromtxt(url, delimiter=',', dtype='float', usecols=[0,1,2,3])
#       7 # Display the first few rows
#       8 print(iris_2d[:5])
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:1990, in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, ndmin, like)
#    1988     fname = os.fspath(fname)
#    1989 if isinstance(fname, str):
# -> 1990     fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1991     fid_ctx = contextlib.closing(fid)
#    1992 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/_datasource.py:192, in open(path, mode, destpath, encoding, newline)
#     155 """
#     156 Open `path` with `mode` and return the file object.
#     157
#    (...)    188
#     189 """
#     191 ds = DataSource(destpath)
# --> 192 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/_datasource.py:529, in DataSource.open(self, path, mode, encoding, newline)
#     526     return _file_openers[ext](found, mode=mode,
#     527                               encoding=encoding, newline=newline)
#     528 else:
# --> 529     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data not found.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot([0, 1, 2, 3, 4, 5,6,7])

plt.show()

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.kdeplot(random.normal(loc=50, scale=5, size=1000), label='normal')
sns.kdeplot(random.binomial(n=100, p=0.5, size=1000), label='binomial')

plt.show()

# %%
pip install ipdb
# Out:
# Collecting ipdb
#   Downloading ipdb-0.13.13-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: ipython>=7.31.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipdb) (9.0.1)
# Requirement already satisfied: decorator in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipdb) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipython>=7.31.1->ipdb) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipython>=7.31.1->ipdb) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipython>=7.31.1->ipdb) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipython>=7.31.1->ipdb) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipython>=7.31.1->ipdb) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipython>=7.31.1->ipdb) (2.19.1)
# Requirement already satisfied: stack_data in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipython>=7.31.1->ipdb) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipython>=7.31.1->ipdb) (5.14.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.31.1->ipdb) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.31.1->ipdb) (0.7.0)
# Requirement already satisfied: wcwidth in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.31.1->ipdb) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from stack_data->ipython>=7.31.1->ipdb) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from stack_data->ipython>=7.31.1->ipdb) (3.0.0)
# Requirement already satisfied: pure-eval in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from stack_data->ipython>=7.31.1->ipdb) (0.2.3)
# Downloading ipdb-0.13.13-py3-none-any.whl (12 kB)
# Installing collected packages: ipdb
# Successfully installed ipdb-0.13.13
# Note: you may need to restart the kernel to use updated packages.

# %%
import ipdb

def multiply(x, y):
    ipdb.set_trace()
    return x * y

multiply(4, 5)
# Out:
# > /var/folders/yq/fj2l6hl13739cbj57_t2s05m0000gn/T/ipykernel_4593/1527383196.py(5)multiply()
#       4     ipdb.set_trace()
# ----> 5     return x * y
#       6
